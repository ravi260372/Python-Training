# %% [markdown]
# <h1>Customer Segmentation<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Dictionary" data-toc-modified-id="Data-Dictionary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Dictionary</a></span></li><li><span><a href="#Data-Aquisition" data-toc-modified-id="Data-Aquisition-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Aquisition</a></span><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Import-data" data-toc-modified-id="Import-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Import data</a></span></li></ul></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Exploration</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Data-review" data-toc-modified-id="Data-review-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Data review</a></span></li><li><span><a href="#Univariate-Descriptive-statistics" data-toc-modified-id="Univariate-Descriptive-statistics-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Univariate Descriptive statistics</a></span></li><li><span><a href="#Multivariate-Correlations-:-Pearsons-Correlation-+-Heatmap" data-toc-modified-id="Multivariate-Correlations-:-Pearsons-Correlation-+-Heatmap-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Multivariate Correlations : Pearsons Correlation + Heatmap</a></span></li><li><span><a href="#Bivariate-Correlations-:-Scatter-Plot" data-toc-modified-id="Bivariate-Correlations-:-Scatter-Plot-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Bivariate Correlations : Scatter Plot</a></span></li></ul></li></ul></li><li><span><a href="#Data-Pre-Processing" data-toc-modified-id="Data-Pre-Processing-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Pre-Processing</a></span></li><li><span><a href="#Clustering-Fundamentals" data-toc-modified-id="Clustering-Fundamentals-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Clustering Fundamentals</a></span></li><li><span><a href="#Heirarchical-Clustering" data-toc-modified-id="Heirarchical-Clustering-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Heirarchical Clustering</a></span><ul class="toc-item"><li><span><a href="#Distance-Measures" data-toc-modified-id="Distance-Measures-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Distance Measures</a></span></li><li><span><a href="#Ward's-Method" data-toc-modified-id="Ward's-Method-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Ward's Method</a></span></li><li><span><a href="#Heirarchical-Clustering-with-Ward's-method" data-toc-modified-id="Heirarchical-Clustering-with-Ward's-method-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Heirarchical Clustering with Ward's method</a></span></li><li><span><a href="#Dendrogram" data-toc-modified-id="Dendrogram-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Dendrogram</a></span></li></ul></li><li><span><a href="#K-Means-Clustering" data-toc-modified-id="K-Means-Clustering-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>K-Means Clustering</a></span><ul class="toc-item"><li><span><a href="#K-Means-Algorithm" data-toc-modified-id="K-Means-Algorithm-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>K-Means Algorithm</a></span></li><li><span><a href="#Choosing-The-Right-Number-Of-Clusters" data-toc-modified-id="Choosing-The-Right-Number-Of-Clusters-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Choosing The Right Number Of Clusters</a></span><ul class="toc-item"><li><span><a href="#Running-the-algorithm" data-toc-modified-id="Running-the-algorithm-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Running the algorithm</a></span></li><li><span><a href="#Plotting-the-WCSS-{Scree-Plot}" data-toc-modified-id="Plotting-the-WCSS-{Scree-Plot}-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Plotting the WCSS {Scree Plot}</a></span></li></ul></li><li><span><a href="#Rerun-the-alogorithm-with-finalized-k-Clusters" data-toc-modified-id="Rerun-the-alogorithm-with-finalized-k-Clusters-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Rerun the alogorithm with finalized k Clusters</a></span></li><li><span><a href="#Clustering-Results" data-toc-modified-id="Clustering-Results-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Clustering Results</a></span><ul class="toc-item"><li><span><a href="#Add-clustering-results" data-toc-modified-id="Add-clustering-results-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Add clustering results</a></span></li><li><span><a href="#Calculate-Cluster-Attribute-Means" data-toc-modified-id="Calculate-Cluster-Attribute-Means-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Calculate Cluster Attribute Means</a></span></li><li><span><a href="#Counting-the-individuals-in-each-segment" data-toc-modified-id="Counting-the-individuals-in-each-segment-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>Counting the individuals in each segment</a></span></li><li><span><a href="#Renaming-Segments" data-toc-modified-id="Renaming-Segments-7.4.4"><span class="toc-item-num">7.4.4&nbsp;&nbsp;</span>Renaming Segments</a></span></li><li><span><a href="#Visualsing-Segements-in-Original-&quot;Un-Transformed-data&quot;" data-toc-modified-id="Visualsing-Segements-in-Original-&quot;Un-Transformed-data&quot;-7.4.5"><span class="toc-item-num">7.4.5&nbsp;&nbsp;</span>Visualsing Segements in Original "Un-Transformed data"</a></span></li></ul></li></ul></li><li><span><a href="#Principal-Components-Analysis-(PCA)" data-toc-modified-id="Principal-Components-Analysis-(PCA)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Principal Components Analysis (PCA)</a></span><ul class="toc-item"><li><span><a href="#What-is-a-Principal-Component" data-toc-modified-id="What-is-a-Principal-Component-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>What is a Principal Component</a></span></li><li><span><a href="#PCA-With-ScikitLearn" data-toc-modified-id="PCA-With-ScikitLearn-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>PCA With ScikitLearn</a></span></li><li><span><a href="#PCA-Results" data-toc-modified-id="PCA-Results-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>PCA Results</a></span></li><li><span><a href="#Visualizing-Component-Loadings" data-toc-modified-id="Visualizing-Component-Loadings-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Visualizing Component Loadings</a></span></li><li><span><a href="#PCA-Transformation-:-Convert-from-&quot;Large-Feature-Set&quot;-to-&quot;PC-Set&quot;" data-toc-modified-id="PCA-Transformation-:-Convert-from-&quot;Large-Feature-Set&quot;-to-&quot;PC-Set&quot;-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>PCA Transformation : Convert from "Large Feature Set" to "PC Set"</a></span></li></ul></li><li><span><a href="#K-Means-Clustering-with-PCA" data-toc-modified-id="K-Means-Clustering-with-PCA-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>K-Means Clustering with PCA</a></span><ul class="toc-item"><li><span><a href="#Fit-K-Means-model-on-PCA-Scores-data" data-toc-modified-id="Fit-K-Means-model-on-PCA-Scores-data-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Fit K-Means model on PCA Scores data</a></span></li><li><span><a href="#Visualing-the-WCSS-{Cluster-Identification}" data-toc-modified-id="Visualing-the-WCSS-{Cluster-Identification}-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Visualing the WCSS {Cluster Identification}</a></span></li><li><span><a href="#Fit-K-Means-with-chosen-clusters" data-toc-modified-id="Fit-K-Means-with-chosen-clusters-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Fit K-Means with chosen clusters</a></span></li><li><span><a href="#K-Means-PCA-results" data-toc-modified-id="K-Means-PCA-results-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>K-Means PCA results</a></span><ul class="toc-item"><li><span><a href="#Adding-Cluster-Results" data-toc-modified-id="Adding-Cluster-Results-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>Adding Cluster Results</a></span></li><li><span><a href="#Calculate-Cluster-Attribute-Mean" data-toc-modified-id="Calculate-Cluster-Attribute-Mean-9.4.2"><span class="toc-item-num">9.4.2&nbsp;&nbsp;</span>Calculate Cluster Attribute Mean</a></span></li><li><span><a href="#Counting-the-individuals-in-each-segment" data-toc-modified-id="Counting-the-individuals-in-each-segment-9.4.3"><span class="toc-item-num">9.4.3&nbsp;&nbsp;</span>Counting the individuals in each segment</a></span></li><li><span><a href="#Renaming-Segments-(PCA-Segments)" data-toc-modified-id="Renaming-Segments-(PCA-Segments)-9.4.4"><span class="toc-item-num">9.4.4&nbsp;&nbsp;</span>Renaming Segments (PCA-Segments)</a></span></li><li><span><a href="#Visualsing-Segements-in-Original-&quot;Un-Transformed-data&quot;" data-toc-modified-id="Visualsing-Segements-in-Original-&quot;Un-Transformed-data&quot;-9.4.5"><span class="toc-item-num">9.4.5&nbsp;&nbsp;</span>Visualsing Segements in Original "Un-Transformed data"</a></span></li></ul></li><li><span><a href="#Comparing-Segmentation-with-PCA+KMeans-v/s-KMeans-Only" data-toc-modified-id="Comparing-Segmentation-with-PCA+KMeans-v/s-KMeans-Only-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Comparing Segmentation with PCA+KMeans v/s KMeans Only</a></span></li></ul></li><li><span><a href="#Exporting-Models" data-toc-modified-id="Exporting-Models-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Exporting Models</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Summary</a></span></li></ul></div>

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# ![Segmentation_Dataset_Dictionary.png](attachment:Segmentation_Dataset_Dictionary.png)

# %% [markdown]
# ## Data Aquisition
#
# ### Libraries

# %%
import numpy as np # numerical array manipulation
import pandas as pd # data wrangling
import scipy # scientific calculations

#These are the visualization libraries. Matplotlib is standard and is what most people use.
#Seaborn works on top of matplotlib, as we mentioned in the course.
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#For standardizing features. We'll use the StandardScaler module.
from sklearn.preprocessing import StandardScaler  

#Hierarchical clustering with the Sci Py library. We'll use the dendrogram and linkage modules.
from scipy.cluster.hierarchy import dendrogram, linkage  

#Sk learn is one of the most widely used libraries for machine learning. We'll use the following module.s
from sklearn.cluster import KMeans # K-Means Clustering  
from sklearn.decomposition import PCA # Principal Components Analysis

# We need to save the models, which we'll use in the next section. We'll use pickle for that.
import pickle

# %% [markdown]
# ### Import data
# On initiail review of the data in excel we notice that the ID column (index=0) is the 1st column that is a unique identifier.
# We will set the ID column as the index  {index_col = 0}
# On importing the data , it will be stored in a pandas DataFrame "df_segmentation" which we can use for further manipulation and analysis

# %%
# Load the data, contained in the segmentation data csv file.
df_segmentation = pd.read_csv("datasets/segmentation data.csv", index_col = 0)

# %% [markdown]
# ## Data Exploration
# We will examine the "head" & "tail" i.e. top 5 & bottom 5 rows of the dataset using the appropriate pandas methods
# Note that this is Descriptive analysis of the data set. Here we just look at the data to gain some insight.
# We do not apply any transformations or changes to the data.
# We will also examine the data types of each attribute (column) of the dataset using the info() method
#
# #### Data review

# %%
# top 5 rows
df_segmentation.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %%
# bottom 5 rows
df_segmentation.tail()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100001996    1               0   47          1  123525           0
# 100001997    1               1   27          1  117744           1
# 100001998    0               0   31          0   86400           0
# 100001999    1               1   24          1   97968           0
# 100002000    0               0   25          0   68416           0
#
#            Settlement size
# ID
# 100001996                0
# 100001997                0
# 100001998                0
# 100001999                0
# 100002000                0

# %%
# dataset information
df_segmentation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 100000001 to 100002000
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              2000 non-null   int64
#  1   Marital status   2000 non-null   int64
#  2   Age              2000 non-null   int64
#  3   Education        2000 non-null   int64
#  4   Income           2000 non-null   int64
#  5   Occupation       2000 non-null   int64
#  6   Settlement size  2000 non-null   int64
# dtypes: int64(7)
# memory usage: 125.0 KB

# %% [markdown]
# #### Univariate Descriptive statistics
# We will apply the describe() method to get the summary statistics *5 number summary" of all the "numerical columns

# %%
# des criptiive statistics of numerical coulmns
df_segmentation.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# ...

# %% [markdown]
# **Inference**
# 1. Sex , Marital Status , Education , Income , Occupation and Settlement Size are actually categorical variables that are encoded hence their summary statistics are meaningless
# 2. Looking at the "count' we notice that there are 2000 observations for every attribute so no null values
# 3. The maximum "Age" is 76 years , the minimum "Age" is 10 years and the mean / average "Age" is ~36 years
# 4. The maximum "Income" is ~310K USD , the minimum "Income" is ~36K USD and the mean "Income" is ~ 121K USD
# 5. Given that "Sex" is encoded as male = 1 , female = 0 , we can infer that ~ 46% customers are male
# 6. Given that "Marital Status" is encoded as non-single / divorced = 1 , non-single (divorced / separated / married / widowed) = 0 , we can infer that ~ 50% of the customers are non-single (divorced / separated / married / widowed)

# %% [markdown]
# #### Multivariate Correlations : Pearsons Correlation + Heatmap
#
# ###### Numerical View of Correlations
# We will examine the "Pearsons Correlation Co-effecient" to examine the "Correlation" between the attributes
# Pearsons Correlation defines the *Linear Dependancy"* between variables
# It ranges from (+1) Strong Positive to (-1) Strong Negative with (0) indicating the variables are *Not linearly Dependant*
# We will apply the corr() method applied to the df-segmentation DataFrame to compute the correlation co-effecients

# %%
# Compute Pearson correlation coefficient for the features in our data set.
# The correlation method in pandas, it has the Pearson correlation set as default.
df_segmentation.corr()
# Out:
#                       Sex  Marital status       Age  Education    Income  \
# Sex              1.000000        0.566511 -0.182885   0.244838 -0.195146
# Marital status   0.566511        1.000000 -0.213178   0.374017 -0.073528
# Age             -0.182885       -0.213178  1.000000   0.654605  0.340610
# Education        0.244838        0.374017  0.654605   1.000000  0.233459
# Income          -0.195146       -0.073528  0.340610   0.233459  1.000000
# Occupation      -0.202491       -0.029490  0.108388   0.064524  0.680357
# Settlement size -0.300803       -0.097041  0.119751   0.034732  0.490881
#
#                  Occupation  Settlement size
# Sex               -0.202491        -0.300803
# Marital status    -0.029490        -0.097041
# Age                0.108388         0.119751
# Education          0.064524         0.034732
# Income             0.680357         0.490881
# Occupation         1.000000         0.571795
# Settlement size    0.571795         1.000000

# %% [markdown]
# Inference :
# 1. Age and Education are highly correlated (+0.65) implying that "Higher the Education , Higher the Age"
# 2. Income and Occupation are highyl correlated (+0.68) implying "Higher the Occupation , Higher the Income"

# %% [markdown]
# ###### Visual View of Correlations
# We will use the Seaborn and Matplotlib plotting libraries to Visualize the Correlations
#
# We'll plot the correlations using a Heat Map. Heat Maps are a great way to visualize correlations using color coding.
#
# We use RdBu as a color scheme, but you can use viridis, Blues, YlGnBu or many others.
#
# We set the range from -1 to 1, as it is the range of the Pearson Correlation.Otherwise the function infers the boundaries from the input.In this case they will be -0,25 to 0,68, as they are the minumum and maximum correlation indeces between our features.
#
# **Note : The Bluer the Square , Higher is the Positive Correlation , The Redder the Square , Higher is the Negative Correlation**

# %%
plt.figure(figsize = (12, 9))
s = sns.heatmap(df_segmentation.corr(),
               annot = True, 
               cmap = 'RdBu',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show();

# %% [markdown]
# Let us plot the Correlations with different color schemes

# %%
# color scheme viridis
plt.figure(figsize = (12, 9))
s = sns.heatmap(df_segmentation.corr(),
               annot = True, 
               cmap = 'viridis',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show();

# %%
# color scheme autumn
plt.figure(figsize = (12, 9))
s = sns.heatmap(df_segmentation.corr(),
               annot = True, 
               cmap = 'autumn',
               vmin = -1, 
               vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
plt.title('Correlation Heatmap')
plt.show();

# %% [markdown]
# #### Bivariate Correlations : Scatter Plot
# Now that we know there exist "Positive" and "negative Correlations" let us visualize these by plotting a scatter plot of 2 variables.
#
# **Scatter Plot of Age v/s Income : Matplotlib**

# %%
# We'll plot the data. We create a 12 by 9 inches figure.
# We have 2000 data points, which we'll scatter across Age and Income, located on positions 2 and 4 in our data set. 
plt.figure(figsize = (12, 9))
plt.scatter(df_segmentation.iloc[:, 2], df_segmentation.iloc[:, 4]) # Column index of Age and Income
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Visualization of relation between Age and Income')
plt.show();

# %% [markdown]
# **Scatter Plot Age v/s Income : Seaborn**

# %%
# Draw Seaborn Scatter Plot to find relationship between age and income
plt.figure(figsize = (12, 9))
ax=sns.scatterplot(x = "Age", y = "Income", data = df_segmentation)
ax.set(xlabel = "Age",
      ylabel = "Income",
      title = "Relation between Age and Income")
plt.show();

# %% [markdown]
# ## Data Pre-Processing
#
# Given that the data is already cleaned , we move to the next step of Pre-Processing i.e. Standardization.
#
# Data sets usually contain numerical features that have been measured in different units, such as height (in inches) and weight (in pounds). A machine learning algorithm would consider weight more important than height only because the values for weight are larger and have higher variability from person to person.
#
# Machine learning algorithms need to consider all features on an even playing field. That means the values for all features must be transformed to the same scale
#
# The process of **transforming numerical features to use the same scale** is known as feature scaling. It’s an important data preprocessing step for most distance-based machine learning algorithms because it can have a significant impact on the performance of your algorithm.
#
# Looking at the "Difference between Minimum and Maximum" values of Income and Age we find a significant difference as illustrated below
#
# ![Standardization_1.png](attachment:Standardization_1.png)
#
# Differenced between Ages is 50 whilst that between Incomes is 50,000. When modelling these features , Age will be completely disreagrded given that 50,000 > 50 i.e. 50 is an insignificant number. The reason being , the model does not know what is Age and what is income thus it will give importance (more weight) to Income and ignore Age.
#
# To overcome this anomaly we need to standardize the values by bringing them to a comparable scale , which is called "Standardization"...
#
#  We Standardize data, so that all features have equal weight. This is important for modelling.
#  In our case Income would be considered much more important than Education for Instance.  We do not know if this is the case, so we would not like to introduce it to our model. This is what is also refered to as **bias**
#
# **Standardization scales, or shifts, the values for each numerical feature in your dataset so that the features have a mean of 0 and standard deviation of 1**

# %% [markdown]
# ![Standardization_2.png](attachment:Standardization_2.png)
#
# We will apply the StandardScaler() method from SKLearn to standardize the data and store this in segmentation_std

# %%
# Standardizing data, so that all features have equal weight. This is important for modelling.
# Instantiate the Standard Scaler
scaler = StandardScaler()

# Fit and Transform the Data and store in another numpy array
segmentation_std = scaler.fit_transform(df_segmentation)

# %%
# look at top 5 rows
segmentation_std[0:5]
# Out:
# array([[-0.91739884, -0.99302433,  2.65361447,  1.60432297,  0.09752361,
#          0.29682303,  1.552326  ],
#        [ 1.09003844,  1.00702467, -1.18713209, -0.06337243,  0.78265438,
#          0.29682303,  1.552326  ],
#        [-0.91739884, -0.99302433,  1.11731585, -0.06337243, -0.83320224,
#         -1.26952539, -0.90972951],
#        [-0.91739884, -0.99302433,  0.77591616, -0.06337243,  1.32838624,
#          0.29682303,  0.32129825],
#        [-0.91739884, -0.99302433,  1.45871554, -0.06337243,  0.73693175,
#          0.29682303,  0.32129825]])

# %% [markdown]
# ## Clustering Fundamentals
#
# Clustering is a set of techniques used to partition data into groups, or clusters. Clusters are loosely defined as groups of data objects that are more similar to other objects in their cluster than they are to data objects in other clusters. In practice, clustering helps identify two qualities of data: Meaningfulness and Usefulness
#
# **Meaningful** clusters expand domain knowledge. For example, in the medical field, researchers applied clustering to gene expression experiments. The clustering results identified groups of patients who respond differently to medical treatments.
#
# **Useful clusters**, on the other hand, serve as an intermediate step in a data pipeline. For example, businesses use clustering for customer segmentation. The clustering results segment customers into groups with similar purchase histories, which businesses can then use to create targeted advertising campaigns.
#
# Goal of Clustering is to "Group Similar Objects" whereby "Objects Within a Group are similar" and "Differences of objects between Groups are Significant". In General we have two types of Clustering "Heirarchical" and "Flat"
#
# ## Heirarchical Clustering
# The concept of hierarchical clustering lies in the construction and analysis of a dendrogram. A dendrogram is a tree-like structure that explains the relationship between all the data points in the system. Example Taxonomy of the Animal Kingdom.
#
# The hierarchical clustering technique has two approaches
# 1. **Agglomerative**: Agglomerative is a bottom-up approach, in which the algorithm starts with taking all data points as single clusters and merging them until one cluster is left.
# 2. **Divisive**: Divisive algorithm is the reverse of the agglomerative algorithm as it is a top-down approach.

# %% [markdown]
# The agglomerative hierarchical clustering algorithm is a popular example of Heirarchical Clustering. To group the datasets into clusters, it follows the bottom-up approach.
#
# Initially consider every data point as an individual Cluster and at every step, merge the nearest pairs of the cluster. (It is a bottom-up method). At first, every dataset is considered as an individual entity or cluster. At every iteration, the clusters merge with different clusters until one cluster is formed.
#
# The algorithm for Agglomerative Hierarchical Clustering is:
#
# 1. Calculate the similarity of one cluster with all the other clusters (calculate proximity matrix)
# 2. Consider every data point as an individual cluster
# 3. Merge the clusters which are highly similar or close to each other.
# 4. Recalculate the proximity matrix for each cluster
# 5. Repeat Steps 3 and 4 until only a single cluster remains.

# %% [markdown]
# ![Agglomarative_clustering_1.png](attachment:Agglomarative_clustering_1.png)
#
# Step-1: Consider each alphabet as a single cluster and calculate the distance of one cluster from all the other clusters.
#
# Step-2: In the second step comparable clusters are merged together to form a single cluster. Let’s say cluster (B) and cluster (C) are very similar to each other therefore we merge them in the second step similarly to cluster (D) and (E) and at last, we get the clusters [(A), (BC), (DE), (F)]
#
# Step-3: We recalculate the proximity according to the algorithm and merge the two nearest clusters([(DE), (F)]) together to form new clusters as [(A), (BC), (DEF)]
#
# Step-4: Repeating the same process; The clusters DEF and BC are comparable and merged together to form a new cluster. We’re now left with clusters [(A), (BCDEF)].
#
# Step-5: At last the two remaining clusters are merged together to form a single cluster [(ABCDEF)].

# %% [markdown]
# Divisive Hierarchical clustering is precisely the opposite of the Agglomerative Hierarchical clustering. In Divisive Hierarchical clustering, we take into account all of the data points as a single cluster and in every iteration, we separate the data points from the clusters which aren’t comparable. In the end, we are left with N clusters
#
# ![Divisive%20Clustering%201.png](attachment:Divisive%20Clustering%201.png)

# %% [markdown]
# ### Distance Measures
# The next Question is how do we find distances between points to cluster them into similar groups. Here we have thre distance measures namely "Eucliean" , "Manhattan" and "Maximum Distance".
#
# The Euclidean distance is the most widely used distance measure when the variables are continuous (either interval or ratio scale).The Euclidean distance between two points calculates the length of a segment connecting the two points. It is the most evident way of representing the distance between two point.
#
# Euclidean distance may not be suitable while measuring the distance between different locations. If we wanted to measure a distance between two retail stores in a city, then Manhattan distance will be more suitable to use, instead of Euclidean distance.The distance between two points in a grid-based on a strictly horizontal and vertical path. The Manhattan distance is the simple sum of the horizontal and vertical components.
#
# ![distances.png](attachment:distances.png)

# %% [markdown]
# ### Ward's Method
# Ward's method is an alternative approach for performing cluster analysis. Basically, it looks at cluster analysis as an analysis of variance problem, instead of using distance metrics or measures of association.
#
# This method involves an agglomerative clustering algorithm. It will start out at the leaves and work its way to the trunk, so to speak. It looks for groups of leaves that form into branches, the branches into limbs and eventually into the trunk. Ward's method starts out with n clusters of size 1 and continues until all the observations are included into one cluster.
#
# This method is most appropriate for quantitative variables, and not binary variables.
#
# Based on the notion that clusters of multivariate observations should be approximately elliptical in shape, we assume that the data from each of the clusters have been realized in a multivariate distribution. Therefore, it would follow that they would fall into an elliptical shape when plotted in a p-dimensional scatter plot.
#
# Let  denote the value for variable k in observation  j belonging to cluster i.
#
# Furthermore, we define:
#
# We sum over all variables, and all of the units within each cluster. We compare individual observations for each variable against the cluster means for that variable.
#
# Note! When the Error Sum of Squares is small, it suggests that our data are close to their cluster means, implying that we have a cluster of like units.
# The total sums of squares is defined the same as always. Here we compare the individual observations for each variable against the grand mean for that variable.
#
# This  $r^{2}$value is interpreted as the proportion of variation explained by a particular clustering of the observations.
#
# ![Wards_Method.png](attachment:Wards_Method.png)
#
# Using Ward's Method we start out with all sample units in n clusters of size 1 each.
#
# In the first step of the algorithm, n - 1 clusters are formed, one of size two and the remaining of size 1. The error sum of squares $r^{2}$ and  values are then computed. The pair of sample units that yield the smallest error sum of squares, or equivalently, the largest $r^{2}$ value will form the first cluster.
#
# Then, in the second step of the algorithm, n - 2 clusters are formed from that n - 1 clusters defined in step 2. These may include two clusters of size 2, or a single cluster of size 3 including the two items clustered in step 1. Again, the value of $r^{2}$ is maximized.
#
# Thus, at each step of the algorithm, clusters or observations are combined in such a way as to minimize the results of error from the squares or alternatively maximize the $r^{2}$value.
#
# The algorithm stops when all sample units are combined into a single large cluster of size n.

# %% [markdown]
# ### Heirarchical Clustering with Ward's method
#
# We will use the "dendrogram" and "linkage" modules from the scipy library for which we need to load the following:
#
# from scipy.cluster.hierarchy import dendrogram, linkage
#
# A dendrogram is a type of **tree diagram** showing hierarchical clustering relationships between similar sets of data. They are frequently used in biology to show clustering between genes or samples, but they can represent any type of grouped data.
#
# We will create clusters from our standarddized data use the "Ward" method of linkage. The output is a "Linkage Matrix".
#
#
# ### Dendrogram
# We visualize the "Linkage Matrix" by plotting the "Dendrogram".
#
# More the distance of the vertical lines in the dendrogram, the more the distance between those clusters. The key to interpreting a dendrogram is to concentrate on the height at which any two objects are joined together
#
# Suppose we have six clusters: P, Q, R, S, T, and U. Cluster Hierarchy Dendrogram of these six observations shown on the scatterplot is as shown below:
#
# ![scat_dendro.png](attachment:scat_dendro.png)

# %% [markdown]
# **Parts of a dendrogram**
# The branches of the dendrogram are called the Clades. These clades are arranged according to how similar or dissimilar they are.
# Each clade of the dendrogram has one or more leaves. P, Q, R, S, T, and U are leaves of the dendrogram:
# 1. Triple (trifolious): P, Q, R
# 2. Double (bifolius): S, T
# 3. Single (simplicifolius): U
#
# ![parts_of_dendrogram.png](attachment:parts_of_dendrogram.png)

# %%
# Perform Hierarchical Clustering. The results are returned as a linkage matrix. 
hier_clust = linkage(segmentation_std, method = 'ward')

# %%
# We plot the results from the Hierarchical Clustering using a Dendrogram. 
# We truncate the dendrogram for better readability. 
# The level p shows only the last p merged clusters in our case we keep it at 5
# We also omit showing the labels for each point.
# We will also not include the color parameter to enable us visualizing the clusters

# create the figure
plt.figure(figsize = (12,9))

# label X and Y Axis
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')

# plot the dendrogram
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5, 
           show_leaf_counts = False, 
           no_labels = True)
plt.show();

# %% [markdown]
# **Interprewting a Dendrogram :**
# 1. The horizontal axis represents the clusters.
# 2. The vertical scale on the dendrogram represent the distance or dissimilarity.
# 3. Each joining (fusion) of two clusters is represented on the diagram by the splitting of a vertical line into two vertical lines.
# 4. The vertical position of the split, shown by a short bar gives the distance (dissimilarity) between the two clusters
#
# **We have 4 Definite Clusters identified by the 4 Colored Line Groups starting from "Distance = 40"**
#
#
# As we notice Heirarchical Clustering is "resource intesive" especially when we have large datasets.Typically we would go for "Flat Clustering". However when we do not have prior knowledge of the dataset it is advisable to go for Heirarchical Clustering to identify the "Clusters" then emply "Flat Clustering" for segmentation..

# %% [markdown]
# ## K-Means Clustering
#
# ### K-Means Algorithm
# The **Kmeans Algorithm** is an Iterative algorithm that divides a group of n datasets into k subgroups /clusters based on the similarity and their mean distance from the centroid of that particular subgroup/ formed.
#
# K, here is the pre-defined number of clusters to be formed by the Algorithm. If K=3, It means the number of clusters to be formed from the dataset is 3
#
# Conventional K-means requires only a few steps. The first step is to randomly select k centroids, where k is equal to the number of clusters you choose. Centroids are data points representing the center of a cluster (Geometrical Center).
#
# The main element of the algorithm works by a two-step process called **expectation-maximization**. The **expectation** step assigns each data point to its nearest centroid. Then, the maximization step computes the mean of all the points for each cluster and sets the new centroid. Here’s what the conventional version of the k-means algorithm looks like:
#
# ![K-Means.png](attachment:K-Means.png)
#
# After choosing a number of clusters and the initial centroids, the expectation-maximization step is repeated until the centroid positions reach convergence and are unchanged
#
# The quality of the cluster assignments is determined by computing the **sum of the squared error (SSE)** after the centroids converge, or match the previous iteration’s assignment. The SSE is defined as the sum of the squared Euclidean distances of each point to its closest centroid. Since this is a measure of error, the objective of k-means is to try to minimize this value.
#
# The random initialization step causes the k-means algorithm to be nondeterministic, meaning that cluster assignments will vary if you run the same algorithm twice on the same dataset. Researchers commonly run several initializations of the entire k-means algorithm and choose the cluster assignments from the initialization with the lowest SSE.
#
#
# The disadvantages of K-Means Clustering include :
# 1. The Squared Eucledian Distance is sensetive to outliers. To overcome this we can use the "K-Median" algorithm which is computationally intensive
# 2. We need to specify the number of clusters before starting. If we choose K too small (K=1) the Centroids will not lie inside the cluster.
# 3. K-means enfoces "Spherical Clusters" the reason is that we are trying to minimize the distance of the "Centroids" in a straight line so if we have clusters that are "elogated" , K-Means will have more difficulty in separating them.

# %% [markdown]
# There’s a robust implementation of k-means clustering in Python from the popular machine learning package scikit-learn.
#
# The KMeans estimator class in scikit-learn is where you set the algorithm parameters before fitting the estimator to the data. The scikit-learn implementation is flexible, providing several parameters that can be tuned.
#
# Here are the parameters used in this example:
#
# 1. *init controls* the initialization technique. The standard version of the k-means algorithm is implemented by setting init to "random". Setting this to "k-means++" employs an advanced trick to speed up convergence, which you’ll use later.
#
# 2. *n_clusters* sets k for the clustering step. This is the most important parameter for k-means.
#
# 3. *n_init* sets the number of initializations to perform. This is important because two runs can converge on different cluster assignments. The default behavior for the scikit-learn algorithm is to perform ten k-means runs and return the results of the one with the lowest SSE.
#
# 4. *max_iter* sets the number of maximum iterations for each initialization of the k-means algorithm
#
# We'll use the k means module from sklearn : from sklearn.cluster import KMeans

# %% [markdown]
# ### Choosing The Right Number Of Clusters
# The number of clusters that we choose for the algorithm shouldn’t be random. Each and Every cluster is formed by calculating and comparing the mean distances of each data points within a cluster from its centroid.
#
# We Can Choose the right number of clusters with the help of the Within-Cluster-Sum-of-Squares (WCSS) method.
#
# WCSS Stands for the sum of the squares of distances of the data points in each and every cluster from its centroid.
#
# The main idea is to minimize the distance between the data points and the centroid of the clusters. The process is iterated until we reach a minimum value for the sum of distances.
#
# There are two methods that are commonly used to evaluate the appropriate number of clusters:
# 1. The elbow method
# 2. The silhouette coefficient
#
# These are often used as complementary evaluation techniques rather than one being preferred over the other. To perform the elbow method, run several k-means, increment k with each iteration, and record the SSE.
#
# **Elbow Method**
# When you plot SSE as a function of the number of clusters, notice that SSE continues to decrease as you increase k. As more centroids are added, the distance from each point to its closest centroid will decrease.
#
# There’s a sweet spot where the SSE curve starts to bend known as the **elbow point**. The x-value of this point is thought to be a reasonable trade-off between error and number of clusters
#
# **Silhouette Coefficient**
# The silhouette coefficient is a measure of cluster cohesion and separation. It quantifies how well a data point fits into its assigned cluster based on two factors:
#
# How close the data point is to other points in the cluster
# How far away the data point is from points in other clusters
# Silhouette coefficient values range between -1 and 1. Larger numbers indicate that samples are closer to their clusters than they are to other clusters.
#
# In the scikit-learn implementation of the silhouette coefficient, the average silhouette coefficient of all the samples is summarized into one score. The silhouette score() function needs a minimum of two clusters, or it will raise an exception.
#
# Loop through values of k again. This time, instead of computing SSE, compute the silhouette coefficient
#
# #### Running the algorithm
# To perform K-means clustering , we consider 1 to 10 clusters, so we build a for loop runs 10 iterations.In addition we run the algortihm at many different starting points - k means++ and we set a random state for reproducibility.

# %%
# Initiatile an empty list to collect the WCSS values
wcss = []

# Run the for loop 10 times to find the WCSS values
for i in range(1,11):
    
    # Instantiate the algorithm with appropriate parameters
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    
    # Fit (train) the algorithm on "Standardized Data" 
    kmeans.fit(segmentation_std)
    
    # Append the WCSS values extracted from "inertia" attribute
    wcss.append(kmeans.inertia_)

# %%
# The lowest SSE value
kmeans.inertia_
# Out:
# 4295.656622405146

# %%
# Final locations of the centroid
kmeans.cluster_centers_
# Out:
# array([[-0.91739884, -0.99302433, -0.70330131, -1.73106782,  0.429093  ,
#          0.53626482,  0.93289165],
#        [-0.91739884,  1.00702467, -0.58582811, -0.04185377,  0.0774213 ,
#          0.48882703,  0.43248785],
#        [-0.91739884, -0.37300914,  2.12103095,  1.63767688,  0.51107666,
#          0.2185056 ,  0.44440102],
#        [-0.91092323, -0.99302433,  0.46397595, -0.06337243,  0.58281782,
#          0.76167481,  0.94078318],
#        [ 0.72585734,  1.00702467, -0.65086266, -0.06337243, -0.97345836,
#         -1.26952539, -0.90972951],
#        [ 1.09003844,  1.00180261, -0.69999127, -0.05901813, -0.03125661,
#          0.37861668,  0.00952359],
#        [-0.91739884, -0.99302433, -0.01915356, -0.6491579 , -0.56602649,
#         -0.7417951 , -0.83472065],
#        [ 0.30664829,  0.64116205,  1.29842422,  1.70601171,  2.34647367,
#          1.55754248,  0.99686226],
#        [ 1.09003844, -0.99302433, -0.21929616, -0.38852058, -0.6628181 ,
# ...

# %%
# The number of iterations required to converge
kmeans.n_iter_
# Out:
# 12

# %% [markdown]
# The cluster assignments are stored as a one-dimensional NumPy array in kmeans.labels_. Here’s a look at the first five predicted labels

# %%
kmeans.labels_[:5]
# Out:
# array([2, 5, 6, 3, 3])

# %% [markdown]
# #### Plotting the WCSS {Scree Plot}
#
# We will have the x-axis as the range of k (k=1:11) and the y-axis as the WCSS values

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot we choose the number of clusters. 
# We look for a kink in the graphic, after which the descent of wcss isn't as pronounced.
plt.style.use("fivethirtyeight")
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss , marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %% [markdown]
# We notice the graph sharply declines till k=4 and then the rate of decline is relatively low. This is our "Elbow Point"
# We validate this with our Heirarchical Clustering method where we found 4 Clusters.

# %% [markdown]
# ### Rerun the alogorithm with finalized k Clusters

# %%
# We run K-means with a fixed number of clusters. In our case 4.
# we store the results in kmeans_results array
kmeans_results = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)

# We divide our data into the four clusters.
kmeans_results.fit(segmentation_std)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# ### Clustering Results
# We will now alanyze the Custers created by the K-Means alogorithm.
#
# #### Add clustering results
# We will add the "Clustering Results" to our data.
# We will add a new column "Segment_K_Means" that will contain the "Segment Identification" for each observation prodicted by the K-Means algorithm.
# The Segment identifications can be extracted from the kmeans.labels_ values from the one-dimensional NumPy array in kmeans_results.labels_
# **Note : We are adding the "Segments" to our original DataFrame segmentation_df" that contains the "Non-Transformed Values"**

# %%
# We create a new data frame with the original features and add a new column with the assigned clusters for each point.
df_segm_kmeans = df_segmentation.copy()
df_segm_kmeans['Segment K-means'] = kmeans_results.labels_
df_segm_kmeans.head(10)
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
# 100000006    0               0   35          1  144848           0
# 100000007    0               0   53          1  156495           1
# 100000008    0               0   35          1  193621           2
# 100000009    0               1   61          2  151591           0
# 100000010    0               1   28          1  174646           2
#
#            Settlement size  Segment K-means
# ID
# 100000001                2                0
# 100000002                2                2
# 100000003                0                1
# ...

# %% [markdown]
# #### Calculate Cluster Attribute Means
# We will now calculate "mean Values" of each attribute in every cluster.
# We will apply the groupby method on every column of the df_segm_kmeans DataFrame and calculate the means.
# We will be grouping the columns by the "Label" stored in the "Segment K-means" column

# %%
# Calculate mean values for the clusters
df_segm_analysis = df_segm_kmeans.groupby(['Segment K-means']).mean()
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.501901        0.692015  55.703422   2.129278
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.853901        0.997163  28.963121   1.068085
# 3                0.029825        0.173684  35.635088   0.733333
#
#                         Income  Occupation  Settlement size
# Segment K-means
# 0                158338.422053    1.129278         1.110266
# 1                 97859.852814    0.329004         0.043290
# 2                105759.119149    0.634043         0.422695
# 3                141218.249123    1.271930         1.522807

# %% [markdown]
# **Interpretation**
# 1. Clsuter 0 : ~50% Females v/s Males , ~70% are "Not-Single", Average age of ~ 58 years , Average Education is "University" , Average Income 158K , Highky Skilled , Mostly living in Big Cities... This is the segment with **"Well Off"**
#
# 2. Cluster 1 : ~65% Males (2/3rd Males) , ~98% are "Single" , Average age of ~36 years , Average Education is "High School" , Average Income ~ 98K , Low on Skills , exclusively living in "Small Citites"... This is the segment with **"Fewer Opportunities"**
#
# 3. Cluster 2 : ~15% Males , ~99% are "Not-Single" , Average age of ~ 29 years , Average education "High School" , Average Income ~ 105K , Middle Management (Skilled) , Living evenly across Small-Mid/Size-Big Cities... This is the segment of average or **"Standard"**
#
# 4. Cluster 3 : ~98% Males , ~85% are "Not-Single" , Average age of ~36 years , Average education is "High School" , Average income ~ 142K , Upper Management (High on skills) , exclusively living in "Mid/Big Cities"... This is the segment of **"Career Focussed"**

# %% [markdown]
# #### Counting the individuals in each segment
# We will now find out the "Proportion" of individuals in each segment.
# We will use the groupby method to count the observations in each segment.
# Note : We need a 2nd argument with groiupby to count the observations in each row which in this case we will choose "Sex"
# We will create 2 new columns 'N_Obs" and "Prop_Obs" to store the values of "Observations Per Row" and "% of Observations"

# %%
## Compute the size and proportions of the four clusters

## Store the Number of observation per row
df_segm_analysis['N Obs'] = df_segm_kmeans[['Segment K-means','Sex']].groupby(['Segment K-means']).count()

## Store the Proportions of observation per row compared to complete observations
df_segm_analysis['Prop Obs'] = df_segm_analysis['N Obs'] / df_segm_analysis['N Obs'].sum()

# %%
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.501901        0.692015  55.703422   2.129278
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.853901        0.997163  28.963121   1.068085
# 3                0.029825        0.173684  35.635088   0.733333
#
#                         Income  Occupation  Settlement size  N Obs  Prop Obs
# Segment K-means
# 0                158338.422053    1.129278         1.110266    263    0.1315
# 1                 97859.852814    0.329004         0.043290    462    0.2310
# 2                105759.119149    0.634043         0.422695    705    0.3525
# 3                141218.249123    1.271930         1.522807    570    0.2850

# %% [markdown]
# #### Renaming Segments
# We will re-name the segments in our "Segmentation" DataFrame by replacing the values 0/1/2/3 with the respective Cluster Names we classified them into using the .rename() method
# Segment 0 -- Well Off
# Segment 1 -- Fewer opportunities
# Segment 2 -- Standard
# Segment 3 -- Career focussed

# %%
# Rename the segments 
df_segm_analysis.rename({0:'well-off',
                         1:'fewer-opportunities',
                         2:'standard',
                         3:'career focused'})
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means
# well-off             0.501901        0.692015  55.703422   2.129278
# fewer-opportunities  0.352814        0.019481  35.577922   0.746753
# standard             0.853901        0.997163  28.963121   1.068085
# career focused       0.029825        0.173684  35.635088   0.733333
#
#                             Income  Occupation  Settlement size  N Obs  \
# Segment K-means
# well-off             158338.422053    1.129278         1.110266    263
# fewer-opportunities   97859.852814    0.329004         0.043290    462
# standard             105759.119149    0.634043         0.422695    705
# career focused       141218.249123    1.271930         1.522807    570
#
#                      Prop Obs
# Segment K-means
# well-off               0.1315
# fewer-opportunities    0.2310
# standard               0.3525
# career focused         0.2850

# %% [markdown]
# **Interpretation**
# 1. Largest Segment is the Standard Segment with 705 individuals (35%)
# 2. Smallest Segment is the Well Off Segment with 263 individuals (13%)

# %% [markdown]
# #### Visualsing Segements in Original "Un-Transformed data"
# We will be visualizing the segments on the "raw data" i.e. "Un-Transformed Data" df_segm_kmeans which is a copy of df_segmentation

# %%
# Review the Data Frame with Segment Classification and Sizes
df_segm_kmeans.head(6)
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
# 100000006    0               0   35          1  144848           0
#
#            Settlement size  Segment K-means
# ID
# 100000001                2                0
# 100000002                2                2
# 100000003                0                1
# 100000004                1                3
# 100000005                1                3
# 100000006                0                1

# %% [markdown]
# We will now add the "Segment Names" by mapping each row of the "Segment K-means" column to the respective "Names" applying the map method. These Segment names will be added in a new column named "Labels"

# %%
# Add the segment labels to our table
df_segm_kmeans['Labels'] = df_segm_kmeans['Segment K-means'].map({0:'well-off', 
                                                                  1:'fewer opportunities',
                                                                  2:'standard', 
                                                                  3:'career focused'})
df_segm_kmeans.head(6)
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
# 100000006    0               0   35          1  144848           0
#
#            Settlement size  Segment K-means               Labels
# ID
# 100000001                2                0             well-off
# 100000002                2                2             standard
# 100000003                0                1  fewer opportunities
# 100000004                1                3       career focused
# 100000005                1                3       career focused
# 100000006                0                1  fewer opportunities

# %% [markdown]
# Let us plot the distribution of "Age v/s Income" by segments i.e. Scatter Plaot of Age vs Income by Segment.
# We will use the "Labels" as hue for the 3rd dimension in the scatter plot

# %%
# We plot the results from the K-means algorithm. Age v/s Income
# Each point in our data set is plotted with the color of the clusters it has been assigned to.
plt.figure(figsize = (10, 8))
sns.scatterplot(data = df_segm_kmeans , 
                x = "Age" , 
                y = "Income" , 
                hue = 'Labels' , 
                palette = ['g', 'r', 'c', 'm'])
plt.title('Segmentation K-means')
plt.show();

# %% [markdown]
# Let us review our segmentation table summary

# %%
df_segm_kmeans.groupby(['Labels']).mean()
# Out:
#                           Sex  Marital status        Age  Education  \
# Labels
# career focused       0.029825        0.173684  35.635088   0.733333
# fewer opportunities  0.352814        0.019481  35.577922   0.746753
# standard             0.853901        0.997163  28.963121   1.068085
# well-off             0.501901        0.692015  55.703422   2.129278
#
#                             Income  Occupation  Settlement size  \
# Labels
# career focused       141218.249123    1.271930         1.522807
# fewer opportunities   97859.852814    0.329004         0.043290
# standard             105759.119149    0.634043         0.422695
# well-off             158338.422053    1.129278         1.110266
#
#                      Segment K-means
# Labels
# career focused                   3.0
# fewer opportunities              1.0
# standard                         2.0
# well-off                         0.0

# %% [markdown]
# **Inference**
# 1. The "Green Segment" i.e. Well Off is clearly seperated based on "Age and Income"
# 2. The Other segments are "Overlapping" and not clearely separable based on Age and Income since the mean Age and Income for the other 3 segments are nearly equal

# %% [markdown]
# ## Principal Components Analysis (PCA)
# Principal Component Analysis (PCA) is a linear dimensionality reduction technique that can be utilized for extracting information from a high-dimensional space by projecting it into a lower-dimensional sub-space. It tries to preserve the essential parts that have more variation of the data and remove the non-essential parts with fewer variation.
#
# Dimensions are nothing but features that represent the data. For example, A 28 X 28 image has 784 picture elements (pixels) that are the dimensions or features which together represent that image.
#
# One important thing to note about PCA is that it is an Unsupervised dimensionality reduction technique, you can cluster the similar data points based on the feature correlation between them without any supervision (or labels)
#
# According to Wikipedia, PCA is a statistical procedure that uses an orthogonal transformation to convert a set of observations of possibly correlated variables (entities each of which takes on various numerical values) into a set of values of linearly uncorrelated variables called principal components.
#
# Note: Features, Dimensions, and Variables are all referring to the same thing. You will find them being used interchangeably.
#
# **Applications of PCA :**
# *Data Visualization:* When working on any data related problem, the challenge in today's world is the sheer volume of data, and the variables/features that define that data. To solve a problem where data is the key, you need extensive data exploration like finding out how the variables are correlated or understanding the distribution of a few variables. Considering that there are a large number of variables or dimensions along which the data is distributed, visualization can be a challenge and almost impossible.Hence, PCA can do that for you since it projects the data into a lower dimension, thereby allowing you to visualize the data in a 2D or 3D space with a naked eye.
#
# *Speeding Machine Learning (ML) Algorithm:* Since PCA's main idea is dimensionality reduction, you can leverage that to speed up your machine learning algorithm's training and testing time considering your data has a lot of features, and the ML algorithm's learning is too slow.
#
# At an abstract level, you take a dataset having many features, and you simplify that dataset by selecting a few Principal Components from original features
#
#
# ### What is a Principal Component
#
# Principal components are the key to PCA; they represent what's underneath the hood of your data. In a layman term, when the data is projected into a lower dimension (assume three dimensions) from a higher space, the three dimensions are nothing but the three Principal Components that captures (or holds) most of the variance (information) of your data.
#
# Principal components have both direction and magnitude. The direction represents across which principal axes the data is mostly spread out or has most variance and the magnitude signifies the amount of variance that Principal Component captures of the data when projected onto that axis. The principal components are a straight line, and the first principal component holds the most variance in the data. Each subsequent principal component is orthogonal to the last and has a lesser variance. In this way, given a set of x correlated variables over y samples you achieve a set of u uncorrelated principal components over the same y samples.
#
# The reason you achieve uncorrelated principal components from the original features is that the correlated features contribute to the same principal component, thereby reducing the original data features into uncorrelated principal components; each representing a different set of correlated features with different amounts of variation.

# %% [markdown]
# ### PCA With ScikitLearn
# We will use the PCA Module from ScikitLearn to decompose our Standardized data into Principal Components
#
# To implement PCA in Scikit learn, it is essential to standardize/normalize the data before applying PCA.
#
# PCA is imported from sklearn.decomposition. We need to select the required number of principal components.
#
# Usually, n_components is chosen to be 2 for better visualization but it matters and depends on data.
#
# By the fit and transform method, the attributes are passed.
#
# The values of principal components can be checked using components_ while the variance explained by each principal component can be calculated using explained_variance_ratio.

# %% [markdown]
# **Step 1 : Create an instance**

# %%
# Create an instance.
pca = PCA()

# %% [markdown]
# **Step 2 : Fit the PCA Instance to Standardized Data**

# %%
segmentation_std[:5]
# Out:
# array([[-0.91739884, -0.99302433,  2.65361447,  1.60432297,  0.09752361,
#          0.29682303,  1.552326  ],
#        [ 1.09003844,  1.00702467, -1.18713209, -0.06337243,  0.78265438,
#          0.29682303,  1.552326  ],
#        [-0.91739884, -0.99302433,  1.11731585, -0.06337243, -0.83320224,
#         -1.26952539, -0.90972951],
#        [-0.91739884, -0.99302433,  0.77591616, -0.06337243,  1.32838624,
#          0.29682303,  0.32129825],
#        [-0.91739884, -0.99302433,  1.45871554, -0.06337243,  0.73693175,
#          0.29682303,  0.32129825]])

# %%
# Fit PCA with our standardized data.
pca.fit(segmentation_std)
# Out:
# PCA()

# %% [markdown]
# PCA Creates segments of Data equal to the number of features in our case 7 Features = 7 Principal Components and components are arranged in their order of importance.
#
# The importance implies "How Much of the Variance" of Data is represented by each "Principal Component" this is termed as "Explained Variance".
#
# We apply the explained_variance_ratio_ method on the decomposed data to understand this Variance

# %% [markdown]
# **Step 3 : Explained Variance**

# %%
# The attribute shows how much variance is explained by each of the seven individual components.
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %% [markdown]
# PCA Applied a Linear Transformation to our data and created 7 New Variables i.e. 7 Principal Components.
#
# These 7 Components together represent 100% of the variability in our data.
#
# Notice some components explain "High Degree of Variance : 1 and 2" whilst some components explain "Low Degree of Variance : 4 through 6
#
# 1st Component = 36% ; 2nd Component = 26% ; 3rd Component = 19% and so on whilst the last Component = 2%

# %% [markdown]
# **Step 4 : Identify number of components to choose : Scree Plot**
# We will plot the cumpulative variance explained against the number of components (Scree Plot)
# We will apply the cumsum() on the explained variance ratio
# x-axis will be number of components in this case 7 , y-axis will be the cumulative explained variance
# We will then select the Number of compoennts that explain cumulative 80% of the variance

# %%
# Plot the cumulative variance explained by total number of components.
# On this graph we choose the subset of components we want to keep. 
# Generally, we want to keep around 80 % of the explained variance.
plt.figure(figsize = (12,9))
plt.plot(range(1,8), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show();

# %% [markdown]
# **Step 5: Re-instantiate PCA with selected components**
# We will chosse 3 Components as they cumulatively explain 80% of the Variance in the Data
# We will re-instantiate PCA with 3 components

# %%
# We choose three components and re-instantiate the PCA
pca = PCA(n_components = 3)

# %% [markdown]
# **Step 6 : Fit the PCA instance on the Standardized Data**

# %%
#Fit the model the our data with the selected number of components. In our case three.
pca.fit(segmentation_std)
# Out:
# PCA(n_components=3)

# %% [markdown]
# ### PCA Results
# Now that we have selected 3 Principal Components , let us understand the details about these components
# We will extract the **"Component Loadings"** of each Principal Component.
# The loadings are the correlations between the components and the original features
#
# The pca.components_ object contains the weights (also called as ‘loadings’) of each Principal Component. It is using these weights that the final principal components are formed.
#
# The key thing to understand is that, each principal component is the dot product of its weights (in pca.components_) and the mean centered data(X). What we mean by ‘mean-centered’ is, each column of the ‘X’ is subtracted from its own mean so that the mean of each column becomes zero.
#
# PCi = Weightsi * Xmeancentred

# %%
# PCA Components
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503]])

# %% [markdown]
# The result is a 3X7... 3 Rows (Each Principal Component) and 7 Columns (Features)
# The Values show the component loading of each feature.
# We will convert this array into a DataFrame consisting of :
# 1. "Row Names as Principal Components"
# 2. "Column Names" as Column Names from the Original Dataset.
# 3. Values of the dataFrame will be the values in the component loading Array
# 4. Index the Data Frame to the Components.
# Note: We use the values attribute to extract the column names

# %%
# Convert to Data Frame of loadings
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = df_segmentation.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3'])
df_pca_comp
# Out:
#                   Sex  Marital status       Age  Education    Income  \
# Component 1 -0.314695       -0.191704  0.326100   0.156841  0.524525
# Component 2  0.458006        0.512635  0.312208   0.639807  0.124683
# Component 3 -0.293013       -0.441977  0.609544   0.275605 -0.165662
#
#              Occupation  Settlement size
# Component 1    0.492059         0.464789
# Component 2    0.014658        -0.069632
# Component 3   -0.395505        -0.295685

# %% [markdown]
# Values vary between (-1) to (+1) and the correlations. Component 1 and Sex are "Negatively Correlated"

# %% [markdown]
# ### Visualizing Component Loadings
# We will visualize the component loadings against each feature by constructing a heatmap

# %%
# Heat Map for Principal Components against original features. Again we use the RdBu color scheme and set borders to -1 and 1.
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu',
            annot = True)
plt.yticks([0, 1, 2], 
           ['PC 1', 'PC 2', 'PC 3'],
           rotation = 45,
           fontsize = 9)
plt.show();

# %% [markdown]
# **Inference**
# 1. Negative Values -- Red , Positive Values -- Blue
# 2. Positive Correlation between PC-1 , Income , Age , Occupation and Settlement Size.These relate to the "Career of a Person" i.e. *Career Focus* of the individual
# 3. Positive Correlation between PC-2 , Sex , Marital Status and Education. Career related features "Income-Occupation-Settlement Size" are almost un-correlated. These relate to the individuals "Education and Lifestyle" i.e. *Lifestyle Focus* of the individual
# 4. Positive Correlation between PC-2 and Age , Negative Correlation between PC-2 , Marital Status and Occupation. These factors describe the "Overall Experience - Work / Life"

# %% [markdown]
# ### PCA Transformation : Convert from "Large Feature Set" to "PC Set"
# Our Original data has 7 features (Dimensions). We have 3 Principal Components that together explain ~80% of the variance in the Original Data set.
# We will now tranform the "Standardized Original Dataset" applying the pca.transform() method

# %%
# Transform
pca.transform(segmentation_std)
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ],
#        [ 0.34493528,  0.59814564, -2.21160279],
#        [-0.65106267, -0.68009318,  2.2804186 ],
#        ...,
#        [-1.45229829, -2.23593665,  0.89657125],
#        [-2.24145254,  0.62710847, -0.53045631],
#        [-1.86688505, -2.45467234,  0.66262172]])

# %% [markdown]
# We now have an Arry of 3 Columns which are the 3 Principal Components. The values are called "PCA Scores".
# We will save these scores in another variable "pca_scores" and continue our analysis

# %%
# PCA Score variable
scores_pca = pca.transform(segmentation_std)

# 1st 5 rows of the array
scores_pca[:5]
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ],
#        [ 0.34493528,  0.59814564, -2.21160279],
#        [-0.65106267, -0.68009318,  2.2804186 ],
#        [ 1.71431626, -0.5799265 ,  0.73073109],
#        [ 1.62674455, -0.44049553,  1.24490888]])

# %% [markdown]
# ## K-Means Clustering with PCA
# We will now perform K-Means Clustering on the PCA transformed + Scored data that has "3 Rows : 1 each per Principal Component".
# Not this PCA Scored data explains ~ 80% of the Variation in the Original Data.
#
# ### Fit K-Means model on PCA Scores data

# %%
# We fit K means using the transformed data from the PCA.

# Initiatile an empty list to collect the WCSS values
wcss = []

# Run the for loop 10 times to find the WCSS values
for i in range(1,11):
    
    # Instantiate the algorithm with appropriate parameters
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    
    # Fit (train) the algorithm on "PCA Transformed Data" 
    kmeans_pca.fit(scores_pca)
    
    # Append the WCSS values extracted from "inertia" attribute
    wcss.append(kmeans_pca.inertia_)

# %%
# The lowest SSE value
kmeans_pca.inertia_
# Out:
# 2018.2549988047201

# %%
# Final locations of the centroid
kmeans_pca.cluster_centers_
# Out:
# array([[ 0.38787184, -2.27848569, -0.47428223],
#        [ 1.08794281, -0.7949022 ,  0.7251939 ],
#        [-2.01293918,  0.57487544, -0.39693388],
#        [ 1.82596859,  2.37548503, -0.11520312],
#        [-0.25608237,  0.4588115 , -1.22610994],
#        [ 2.43302969, -0.88026816, -0.68714303],
#        [-0.54921023,  2.16598591,  1.64556844],
#        [-1.03549934, -0.47161503,  1.28209407],
#        [ 2.86126559,  0.99400089,  1.86375875],
#        [-1.81269633, -2.07324433,  0.44353498]])

# %%
# The number of iterations required to converge
kmeans_pca.n_iter_
# Out:
# 9

# %% [markdown]
# ### Visualing the WCSS {Cluster Identification}

# %%
# Plot the Within Cluster Sum of Squares for the different number of clusters.
# From this plot we choose the number of clusters. 
# We look for a kink in the graphic, after which the descent of wcss isn't as pronounced.
plt.style.use("fivethirtyeight")
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss , marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show();

# %% [markdown]
# We notice the graph sharply declines till k=4 and then the rate of decline is relatively low. This is our "Elbow Point"

# %% [markdown]
# ### Fit K-Means with chosen clusters

# %%
# We have chosen four clusters, so we run K-means with number of clusters equals four. 
# Same initializer and random state as before.
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)

# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# ### K-Means PCA results
# We will now interpret the results of K-Means Clustering with PCA
#
# #### Adding Cluster Results
#
# We create a "new dataframe" by combining the scores_pca and the original data frame i.e. add **new columns** from "scores_pca" to the original dataframe
#
# We will add a new column "Segment_K_Means_PCA" that will contain the "Segment Identification" for each observation prodicted by the K-Means algorithm applied on the PCA data.
#
# The Segment identifications can be extracted from the kmeans.labels_ values from the one-dimensional NumPy array in kmeans_results.labels_
#
# **Note : We are adding the "Segments" to our original DataFrame segmentation_df" that contains the "Non-Transformed Values"**

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters.
df_segm_pca_kmeans = pd.concat([df_segmentation.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)

# Add labels to the combined colums i.e. PCA-1/2/3
df_segm_pca_kmeans.columns.values[-3: ] = ['PC-1', 'PC-2', 'PC-3']

# The last column we add contains the pca k-means clustering labels.
df_segm_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

df_segm_pca_kmeans.head(6)
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
# 5    0               0   35          1  144848           0                0
#
#        PC-1      PC-2      PC-3  Segment K-means PCA
# 0  2.514746  0.834122  2.174806                    3
# 1  0.344935  0.598146 -2.211603                    0
# 2 -0.651063 -0.680093  2.280419                    2
# 3  1.714316 -0.579927  0.730731                    1
# 4  1.626745 -0.440496  1.244909                    1
# 5 -0.274734 -0.871070  1.310152                    2

# %%
df_segm_pca_kmeans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sex                  2000 non-null   int64
#  1   Marital status       2000 non-null   int64
#  2   Age                  2000 non-null   int64
#  3   Education            2000 non-null   int64
#  4   Income               2000 non-null   int64
#  5   Occupation           2000 non-null   int64
#  6   Settlement size      2000 non-null   int64
#  7   PC-1                 2000 non-null   float64
#  8   PC-2                 2000 non-null   float64
#  9   PC-3                 2000 non-null   float64
#  10  Segment K-means PCA  2000 non-null   int32
# dtypes: float64(3), int32(1), int64(7)
# memory usage: 164.2 KB

# %% [markdown]
# This is our final resultant table containing the original data , the Principal Component Scores and the Segment Labels

# %% [markdown]
# #### Calculate Cluster Attribute Mean
#
# We will create a new Dataframe that stores the mean values

# %%
# We calculate the means by segments.
df_segm_pca_kmeans_freq = df_segm_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.900289        0.965318  28.878613   1.060694
# 1                    0.027444        0.168096  35.737564   0.734134
# 2                    0.306522        0.095652  35.313043   0.760870
# 3                    0.505660        0.690566  55.679245   2.128302
#
#                             Income  Occupation  Settlement size      PC-1  \
# Segment K-means PCA
# 0                    107551.500000    0.677746         0.440751 -1.107019
# 1                    141525.826758    1.267581         1.480274  1.372663
# 2                     93692.567391    0.252174         0.039130 -1.046406
# 3                    158019.101887    1.120755         1.101887  1.687328
#
#                          PC-2      PC-3
# Segment K-means PCA
# 0                    0.703776 -0.781410
# 1                   -1.046172 -0.248046
# 2                   -0.902963  1.003644
# ...

# %% [markdown]
# #### Counting the individuals in each segment
# We will now find out the "Proportion" of individuals in each segment.
# We will use the groupby method to count the observations in each segment. We are referring to the "new dataframe df_segm_pca_kmeans" created earlier.
# Note : We need a 2nd argument with groiupby to count the observations in each row which in this case we will choose "Sex"
# We will create 2 new columns 'N_Obs" and "Prop_Obs" to store the values of "Observations Per Row" and "% of Observations"

# %%
## Compute the size and proportions of the four clusters

## Store the Number of observation per row
df_segm_pca_kmeans_freq['N Obs'] = df_segm_pca_kmeans[['Segment K-means PCA','Sex']].groupby(['Segment K-means PCA']).count()

## Store the Proportions of observation per row compared to complete observations
df_segm_pca_kmeans_freq['Prop Obs'] = df_segm_pca_kmeans_freq['N Obs'] / df_segm_pca_kmeans_freq['N Obs'].sum()

# %%
df_segm_pca_kmeans_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              4 non-null      float64
#  1   Marital status   4 non-null      float64
#  2   Age              4 non-null      float64
#  3   Education        4 non-null      float64
#  4   Income           4 non-null      float64
#  5   Occupation       4 non-null      float64
#  6   Settlement size  4 non-null      float64
#  7   PC-1             4 non-null      float64
#  8   PC-2             4 non-null      float64
#  9   PC-3             4 non-null      float64
#  10  N Obs            4 non-null      int64
#  11  Prop Obs         4 non-null      float64
# dtypes: float64(11), int64(1)
# memory usage: 416.0 bytes

# %%
df_segm_pca_kmeans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sex                  2000 non-null   int64
#  1   Marital status       2000 non-null   int64
#  2   Age                  2000 non-null   int64
#  3   Education            2000 non-null   int64
#  4   Income               2000 non-null   int64
#  5   Occupation           2000 non-null   int64
#  6   Settlement size      2000 non-null   int64
#  7   PC-1                 2000 non-null   float64
#  8   PC-2                 2000 non-null   float64
#  9   PC-3                 2000 non-null   float64
#  10  Segment K-means PCA  2000 non-null   int32
# dtypes: float64(3), int32(1), int64(7)
# memory usage: 164.2 KB

# %%
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.900289        0.965318  28.878613   1.060694
# 1                    0.027444        0.168096  35.737564   0.734134
# 2                    0.306522        0.095652  35.313043   0.760870
# 3                    0.505660        0.690566  55.679245   2.128302
#
#                             Income  Occupation  Settlement size      PC-1  \
# Segment K-means PCA
# 0                    107551.500000    0.677746         0.440751 -1.107019
# 1                    141525.826758    1.267581         1.480274  1.372663
# 2                     93692.567391    0.252174         0.039130 -1.046406
# 3                    158019.101887    1.120755         1.101887  1.687328
#
#                          PC-2      PC-3  N Obs  Prop Obs
# Segment K-means PCA
# 0                    0.703776 -0.781410    692    0.3460
# 1                   -1.046172 -0.248046    583    0.2915
# ...

# %% [markdown]
# #### Renaming Segments (PCA-Segments)
# We will re-name the segments in our "Segmentation" DataFrame by replacing the values 0/1/2/3 with the respective Cluster Names
# Recall the Characteristics of Principal Components that we identified earlier :
#
# 1. PC1 = Career Focus of the individual
# 2. PC2 = Education Lifestyle Focus of the individual
# 3. PC3 = Overall Experience - Work / Life
#
# **Segment 3 : High on PC1 (career) , High on PC2 (lifestyle) , High on PC3 (experience)--- These would be "Well Off Individuals"**
# **Segment 2 : High on PC3 (experience) , Strongly Negative on PC1 (career) and PC2 (lifestyle) --- These individuals have fewer opportunities despite higher experience. These would be "Fewer Opportunities"**
# **Segment 1 : High on PC1 (career) , Strongly Negative on PC2 (lifestyle) , Moderately Negative on PC3 (experience) --- These are "Career Focussed"**
# **Segment 0 : Normal/High on PC2 (lifestyle) ; Strongly Negative on PC1 (career) and Moderately Negative on PC3 (experience).These individuals are the youngest of the lot i.e. "Standard People"**

# %% [markdown]
# Let us re-name the "Index" of the Dataframe with "Segment Names"

# %%
# Add the segment labels to our table
df_segm_pca_kmeans_freq = df_segm_pca_kmeans_freq.rename({0:'standard', 
                                                          1:'career focused',
                                                          2:'fewer opportunities', 
                                                          3:'well-off'})
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# standard             0.900289        0.965318  28.878613   1.060694
# career focused       0.027444        0.168096  35.737564   0.734134
# fewer opportunities  0.306522        0.095652  35.313043   0.760870
# well-off             0.505660        0.690566  55.679245   2.128302
#
#                             Income  Occupation  Settlement size      PC-1  \
# Segment K-means PCA
# standard             107551.500000    0.677746         0.440751 -1.107019
# career focused       141525.826758    1.267581         1.480274  1.372663
# fewer opportunities   93692.567391    0.252174         0.039130 -1.046406
# well-off             158019.101887    1.120755         1.101887  1.687328
#
#                          PC-2      PC-3  N Obs  Prop Obs
# Segment K-means PCA
# standard             0.703776 -0.781410    692    0.3460
# career focused      -1.046172 -0.248046    583    0.2915
# ...

# %% [markdown]
# #### Visualsing Segements in Original "Un-Transformed data"
# We will be visualizing the segments on the "raw data" i.e. "Un-Transformed Data" df_segm_kmeans which is a copy of df_segmentation
# Till now we are dealing with the "df_segm_pca_kmeans_freq" dataframe that cotains labels but we have to also label the dataframe that contains the "Principal Components".
#
# We will now add the "Segment Names" by adding a new column "Legend" and map each row of the "df_segm_pca_kmeans" column to the respective "Names" applying the map method. These Segment names will be added in a new column named "Labels"

# %%
df_segm_pca_kmeans['Legend'] = df_segm_pca_kmeans['Segment K-means PCA'].map({0:'standard', 
                                                          1:'career focused',
                                                          2:'fewer opportunities', 
                                                          3:'well-off'})

# %%
df_segm_pca_kmeans.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
#
#        PC-1      PC-2      PC-3  Segment K-means PCA               Legend
# 0  2.514746  0.834122  2.174806                    3             well-off
# 1  0.344935  0.598146 -2.211603                    0             standard
# 2 -0.651063 -0.680093  2.280419                    2  fewer opportunities
# 3  1.714316 -0.579927  0.730731                    1       career focused
# 4  1.626745 -0.440496  1.244909                    1       career focused

# %% [markdown]
# We have 3 Principal Components with Varaince Explained as follows :  PC1 = 36% ; PC2 = 26% ; PC3 = 19%...
# Let us visualize the Segments with he Y axis is the first component (PC1), X axis is the second component (PC2).
# We will label the axes as "y-axis = PC1-Career Focussed" and "x-axis = PC2-Education+Lifestyle Focussed"
# We will chosse the "hue parameter as the Cluster Legend" from the "legend column".
# Since we have 4 clusters we will choose colors

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the second.
plt.figure(figsize = (10, 8))
sns.scatterplot(data = df_segm_pca_kmeans , 
                x = "PC-2" , 
                y = "PC-1" , 
                hue = 'Legend' , 
                palette = ['g', 'r', 'c', 'm'])
plt.xlabel('PC2-Education + Lifestyle Focussed')
plt.ylabel('PC1-Career Focussed')
plt.title('Clusters by PCA Components')
plt.show();

# %%
# Plot data by PCA components. The Y axis is the first component, X axis is the 3rd.
plt.figure(figsize = (10, 8))
sns.scatterplot(data = df_segm_pca_kmeans , 
                x = "PC-3" , 
                y = "PC-1" , 
                hue = 'Legend' , 
                palette = ['g', 'r', 'c', 'm'])
plt.xlabel('PC3-Overall Experience')
plt.ylabel('PC1-Career Focussed')
plt.title('Clusters by PCA Components')
plt.show();

# %% [markdown]
# ### Comparing Segmentation with PCA+KMeans v/s KMeans Only
# We saw that with PCA + KMeans , the two Clusters (Well Off and Career Focussed) are clearly separated whilst Standard and Fewewr Opportunities have some overlap).
# Let us visually compare the Segmentaion with PCA + Kmeans and Segmentation with K-Means only.
# We notice how PCA+KMeans has well defined clusters whereas in KMeans only we have only the Well Off Cluster clearly defined

# %%
# Here we create a figure instance, and two subplots
fig = plt.figure(figsize = (15,15))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# We use ax parameter to tell seaborn which subplot to use for this plot
# PCA + KMeans Clustering 
sns.scatterplot(data = df_segm_pca_kmeans , 
                x = "PC-2" , 
                y = "PC-1" , 
                hue = 'Legend' , 
                palette = ['g', 'r', 'c', 'm'] , 
                ax = ax1)
ax1.set_xlabel('PC1-Career Focussed')
ax1.set_ylabel('PC2-Education + Lifestyle Focussed')
ax1.set_title('Segmentation PCA + KMeans')

# Only KMeans Clustering
sns.scatterplot(data = df_segm_kmeans , 
                x = "Age" , 
                y = "Income" , 
                hue = 'Labels' , 
                palette = ['g', 'r', 'c', 'm'] , 
                ax = ax2)
ax2.set_xlabel('Age')
ax2.set_ylabel('Income')
ax2.set_title('Segmentation KMeans Only')
plt.show();

# %% [markdown]
# ## Exporting Models
# We have successfully segmented our data by creating a PCA+Kmeans Model.
# We will use this model for further use hence we need to save it.
# We'll use pickle for that. Pickle is a module that converts Python objects into strings (import pickle).
# We will import the model in a different notebokk for further analysis
#
# Step 1 : Export the Model we created for "Standardizing the Data".This is the "scaler" object we created in the Data Preprocessing Setion
# Step 2 : Export the Model we created for "Principal Components Decomposition". This is the "pca" object we created in the PCA section
# Step 3 : Export the Clustering Model created for "Segmentation". This is the "kmeans_pca" object we created in the K Means Clustering with PCA section
#
# We export models by applying the dump() method on the pickle object with arguments that include the "model name"
#
# We will apply these models on new data points later

# %%
# We save the objects we'll need in the Purchase Analytics part of the course. We export them as pickle objects.
# We need the scaler, pca and kmeans_pca objects to preprocess and segment the purchase data set.

# Export Scaler Model
pickle.dump(scaler, open('scaler.pickle', 'wb'))

# Export PCA Model
pickle.dump(pca, open('pca.pickle', 'wb'))

# Export Kmeans PCA Model
pickle.dump(kmeans_pca, open('kmeans_pca.pickle', 'wb'))

# %% [markdown]
# ![pikle_files.png](attachment:pikle_files.png)

# %%
kmeans_pca.labels_
# Out:
# array([3, 0, 2, ..., 2, 0, 2])

# %% [markdown]
# ## Summary
# Step 1 : Standardize all numerical variables applying the Standard Scaler and store in "Scaler Object"
# Step 2 : Apply Heirarchical Clustering to get the 1st feel of the Data
# Step 3 : Employ PCA to find a subset of components, which explain the variance in the data
# Step 4 : Coose the requisite components that explain ~80% variation and create the "Pca Object"
# Step 5 : Created the pca_scres object that stores the PCA scores by component
# Step 6 : Fit the K-Means algorithm on pca_scores object
# Step 7 : Identify the right amount of clusters based on the "scree plot"
# Step 8 : Fit the K-Means model with approproate clusters on pca_scres object
# Step 9 : Create a new data frame with the original features and add the PCA scores and assigned clusters
# Step 10 : Add the  pca k-means clustering labels
# Step 11 : Calculate the means by segments
# Step 12 : Calculate the size of each cluster and its proportion to the entire data set
# Step 13 : Add the "Legends" column by "mapping" the labels of the "df_segm_pca_kmeans" column to the respective "Names" applying the map method. These Segment names will be added in a new column named "Labels"
# Step 14 : Save the "scaler" , "pca" and "kmeans_pca" models for further use
